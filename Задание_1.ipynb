# %% [markdown]
# <a href="https://colab.research.google.com/github/valera-oldman54/vvsu-ml-1/blob/main/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание по практике 1

# %% [markdown]
# ##Загрузка датасета
# В файле classification datasets расположены ссылки на датасеты. Выберите один в соответствии со своим вариантом, скачайте и прочитайте файл
#
# **Не забудьте загрузить нужные библиотеки**
#
# Например: pip3 install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/ca_law_enforcement_by_agency.csv")
df
# Out:
#    State/Tribal/Other                                   Agency  \
# 0       State Agencies               Atascadero State Hospital
# 1       State Agencies                   California State Fair
# 2       State Agencies                 Coalinga State Hospital
# 3       State Agencies      Department of Parks and Recreation
# 4       State Agencies           Fairview Developmental Center
# 5       State Agencies                     Napa State Hospital
# 6       State Agencies                   Patton State Hospital
# 7       State Agencies        Porterville Developmental Center
# 8       State Agencies             Sonoma Developmental Center
# 9      Tribal Agencies                    Coyote Valley Tribal
# 10     Tribal Agencies                     Hoopa Valley Tribal
# 11     Tribal Agencies                         La Jolla Tribal
# 12     Tribal Agencies                      Los Coyotes Tribal
# 13     Tribal Agencies                           Sycuan Tribal
# 14     Tribal Agencies                Table Mountain Rancheria
# 15     Tribal Agencies                       Tule River Tribal
# 16     Tribal Agencies                            Yurok Tribal
# 17      Other Agencies                 East Bay Regional Parks
# 18      Other Agencies         Fontana Unified School District
# 19      Other Agencies              Monterey Peninsula Airport
# 20      Other Agencies                Port of San Diego Harbor
# 21      Other Agencies  San Bernardino Unified School District
# 22      Other Agencies    San Francisco Bay Area Rapid Transit
# 23      Other Agencies                   Shasta County Marshal
# 24      Other Agencies        Stockton Unified School District
# 25      Other Agencies     Twin Rivers Unified School District
#
#             Unit/Office  Total law\renforcement\remployees  Total\rofficers  \
# 0                   NaN                                139              128
# 1                   NaN                                  3                3
# 2                   NaN                                228              210
# 3               Capital                                560              530
# 4                   NaN                                 17               14
# 5                   NaN                                114              107
# 6                   NaN                                 85               69
# 7                   NaN                                 50               47
# 8                   NaN                                 17                7
# 9                   NaN                                  6                5
# 10                  NaN                                 18                6
# 11                  NaN                                  2                2
# 12                  NaN                                  6                6
# 13                  NaN                                 19               11
# 14                  NaN                                 24               15
# 15                  NaN                                 27                7
# 16                  NaN                                 11                9
# 17       Alameda County                                 81               59
# 18                  NaN                                 68               16
# 19                  NaN                                  7                7
# 20                  NaN                                152              122
# 21                  NaN                                 72               23
# 22  Contra Costa County                                285              197
# 23                  NaN                                 24               20
# 24                  NaN                                 27               20
# 25                  NaN                                 27               22
#
#     Total\rcivilians
# 0                 11
# 1                  0
# 2                 18
# 3                 30
# 4                  3
# 5                  7
# 6                 16
# 7                  3
# 8                 10
# 9                  1
# 10                12
# 11                 0
# 12                 0
# 13                 8
# 14                 9
# 15                20
# 16                 2
# 17                22
# 18                52
# 19                 0
# 20                30
# 21                49
# 22                88
# 23                 4
# 24                 7
# 25                 5

# %% [markdown]
# ##Первое знакомство с датасетом
# В следующих ячейках выведите:
#
#
# 1.   Колонки датасета
# 2.   Первые 5 значений
# 3.   Последние 5 значений
# 4.   Статистику по числовым колонкам

# %%
#Колонки
df.columns
df.iloc[[]]
# Out:
# Empty DataFrame
# Columns: [State/Tribal/Other , Agency, Unit/Office, Total law
# enforcement
# employees, Total
# officers, Total
# civilians]
# Index: []

# %%
#Первые 5 значений
df.head()
# Out:
#   State/Tribal/Other                               Agency Unit/Office  \
# 0      State Agencies           Atascadero State Hospital         NaN
# 1      State Agencies               California State Fair         NaN
# 2      State Agencies             Coalinga State Hospital         NaN
# 3      State Agencies  Department of Parks and Recreation     Capital
# 4      State Agencies       Fairview Developmental Center         NaN
#
#    Total law\renforcement\remployees  Total\rofficers  Total\rcivilians
# 0                                139              128                11
# 1                                  3                3                 0
# 2                                228              210                18
# 3                                560              530                30
# 4                                 17               14                 3

# %%
#Последние 5 значений
df.tail()
# Out:
#    State/Tribal/Other                                   Agency  \
# 21      Other Agencies  San Bernardino Unified School District
# 22      Other Agencies    San Francisco Bay Area Rapid Transit
# 23      Other Agencies                   Shasta County Marshal
# 24      Other Agencies        Stockton Unified School District
# 25      Other Agencies     Twin Rivers Unified School District
#
#             Unit/Office  Total law\renforcement\remployees  Total\rofficers  \
# 21                  NaN                                 72               23
# 22  Contra Costa County                                285              197
# 23                  NaN                                 24               20
# 24                  NaN                                 27               20
# 25                  NaN                                 27               22
#
#     Total\rcivilians
# 21                49
# 22                88
# 23                 4
# 24                 7
# 25                 5

# %%
#Статистику
df.describe()
# Out:
#        Total law\renforcement\remployees  Total\rofficers  Total\rcivilians
# count                          26.000000        26.000000         26.000000
# mean                           79.576923        63.923077         15.653846
# std                           121.414389       112.015329         20.409688
# min                             2.000000         2.000000          0.000000
# 25%                            17.000000         7.000000          3.000000
# 50%                            27.000000        18.000000          8.500000
# 75%                            84.000000        66.500000         19.500000
# max                           560.000000       530.000000         88.000000

# %% [markdown]
# **Ответьте на следующие вопросы:**
#
#
# 1.   Какие средние значения в каждой числовой колонке вашего датасета?
# 2.   Минимальные и максимальные значения в каждой числовой колонке вашего датасета

# %% [markdown]
# 1.   **Ответ 1.**

# %%
df.describe().iloc[[1]]
# Out:
#       Total law\renforcement\remployees  Total\rofficers  Total\rcivilians
# mean                          79.576923        63.923077         15.653846

# %% [markdown]
# 2.**Ответ 2.**

# %%
df.describe().iloc[[3, 7]]
# Out:
#      Total law\renforcement\remployees  Total\rofficers  Total\rcivilians
# min                                2.0              2.0               0.0
# max                              560.0            530.0              88.0

# %% [markdown]
# ##Типизация
# Присвойте соответствующим колонкам один из типов (category, float, int)

# %%
df["Total\rcivilians"] = df["Total\rcivilians"].astype("int")
df["Total\rofficers"] = df["Total\rofficers"].astype("int")
df["Total law\renforcement\remployees"] = df["Total law\renforcement\remployees"].astype("int")

#df.dtypes[["Total\rcivilians","Total\rofficers","Total law\renforcement\remployees"]]
df.info()

#Вывести типы колонок тут
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 6 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   State/Tribal/Other               26 non-null     object
#  1   Agency                           26 non-null     object
#  2   Unit/Office                      3 non-null      object
# employees  26 non-null     int64
# officers                   26 non-null     int64
# civilians                  26 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 1.3+ KB

# %% [markdown]
# Какие признаки вы можете выделить в своем датасете (категориальные, числовые и др., **минимум 3 разных**, помните что можно также выделить признаки более точно, например числовые - порядковые, количественные и т.д.)?

# %% [markdown]
# ##Фильтрация
# Офильтруйте 3 колонки вашего датасета и выведите результат

# %%
#Фильтр колонки 1
df[df["Total\rcivilians"] > 25]
# Out:
#    State/Tribal/Other                                   Agency  \
# 3       State Agencies      Department of Parks and Recreation
# 18      Other Agencies         Fontana Unified School District
# 20      Other Agencies                Port of San Diego Harbor
# 21      Other Agencies  San Bernardino Unified School District
# 22      Other Agencies    San Francisco Bay Area Rapid Transit
#
#             Unit/Office  Total law\renforcement\remployees  Total\rofficers  \
# 3               Capital                                560              530
# 18                  NaN                                 68               16
# 20                  NaN                                152              122
# 21                  NaN                                 72               23
# 22  Contra Costa County                                285              197
#
#     Total\rcivilians
# 3                 30
# 18                52
# 20                30
# 21                49
# 22                88

# %%
#Фильтр колонки 2
df[df["Total\rofficers"] > 25]
# Out:
#    State/Tribal/Other                                 Agency  \
# 0       State Agencies             Atascadero State Hospital
# 2       State Agencies               Coalinga State Hospital
# 3       State Agencies    Department of Parks and Recreation
# 5       State Agencies                   Napa State Hospital
# 6       State Agencies                 Patton State Hospital
# 7       State Agencies      Porterville Developmental Center
# 17      Other Agencies               East Bay Regional Parks
# 20      Other Agencies              Port of San Diego Harbor
# 22      Other Agencies  San Francisco Bay Area Rapid Transit
#
#             Unit/Office  Total law\renforcement\remployees  Total\rofficers  \
# 0                   NaN                                139              128
# 2                   NaN                                228              210
# 3               Capital                                560              530
# 5                   NaN                                114              107
# 6                   NaN                                 85               69
# 7                   NaN                                 50               47
# 17       Alameda County                                 81               59
# 20                  NaN                                152              122
# 22  Contra Costa County                                285              197
#
#     Total\rcivilians
# 0                 11
# 2                 18
# 3                 30
# 5                  7
# 6                 16
# 7                  3
# 17                22
# 20                30
# 22                88

# %%
#Фильтр колонки 3
df[df["Total law\renforcement\remployees"] > 25]
# Out:
#    State/Tribal/Other                                   Agency  \
# 0       State Agencies               Atascadero State Hospital
# 2       State Agencies                 Coalinga State Hospital
# 3       State Agencies      Department of Parks and Recreation
# 5       State Agencies                     Napa State Hospital
# 6       State Agencies                   Patton State Hospital
# 7       State Agencies        Porterville Developmental Center
# 15     Tribal Agencies                       Tule River Tribal
# 17      Other Agencies                 East Bay Regional Parks
# 18      Other Agencies         Fontana Unified School District
# 20      Other Agencies                Port of San Diego Harbor
# 21      Other Agencies  San Bernardino Unified School District
# 22      Other Agencies    San Francisco Bay Area Rapid Transit
# 24      Other Agencies        Stockton Unified School District
# 25      Other Agencies     Twin Rivers Unified School District
#
#             Unit/Office  Total law\renforcement\remployees  Total\rofficers  \
# 0                   NaN                                139              128
# 2                   NaN                                228              210
# 3               Capital                                560              530
# 5                   NaN                                114              107
# 6                   NaN                                 85               69
# 7                   NaN                                 50               47
# 15                  NaN                                 27                7
# 17       Alameda County                                 81               59
# 18                  NaN                                 68               16
# 20                  NaN                                152              122
# 21                  NaN                                 72               23
# 22  Contra Costa County                                285              197
# 24                  NaN                                 27               20
# 25                  NaN                                 27               22
#
#     Total\rcivilians
# 0                 11
# 2                 18
# 3                 30
# 5                  7
# 6                 16
# 7                  3
# 15                20
# 17                22
# 18                52
# 20                30
# 21                49
# 22                88
# 24                 7
# 25                 5

# %% [markdown]
# ##Группировка
# Сгруппируйте датасет по какому-либо категориальному признаку и выведите среднее значение численных колонок (см. метод mean в pandas)

# %%
#Группировка
#df.groupby(["Total law\renforcement\remployees"]).mean()
df.groupby(["State/Tribal/Other "]).mean()
#samara
#df.describe().iloc[[1]]
# Out:
# <ipython-input-57-02296c96d0fb>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(["State/Tribal/Other "]).mean()
#                      Total law\renforcement\remployees  Total\rofficers  \
# State/Tribal/Other
# Other Agencies                               82.555556        54.000000
# State Agencies                              134.777778       123.888889
# Tribal Agencies                              14.125000         7.625000
#
#                      Total\rcivilians
# State/Tribal/Other
# Other Agencies              28.555556
# State Agencies              10.888889
# Tribal Agencies              6.500000

# %% [markdown]
# ##Задание для гениев *
# Агрегируйте числовой признак по категориальному признаку с использованием метода **без использования** библиотеки pandas, и вычислите медиану и среднее значение для каждой категории.

# %%
#Агрегация
